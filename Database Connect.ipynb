# %%
import pandas as pd 
import psycopg2
from sqlalchemy import create_engine

host = 'cityscrape.cmkoqli3hwbd.us-east-1.rds.amazonaws.com'
port = 5432
user = 'cityscrapeMaster'
password = 'JHjcWXmA?u4bpeaGKmsrQ8j48,Ad'
dbname = 'cityscrape'

try:
    conn = psycopg2.connect(host = host, port=port, user = user, password = password, dbname = dbname)
except:
    print("I am unable to connect to the database")

# %%
host = '127.0.0.1'
port = 5432
user = 'vanguiano'
password = 'V1DaL1T0'
dbname = 'chiscrape_local'

try:
    conn = psycopg2.connect(host = host, port=port, user = user, password = password, dbname = dbname)
except:
    print("I am unable to connect to the database")

# %%
cur = conn.cursor()

# %%
create = '''
CREATE TABLE webpage_data (
    city            varchar(80),
    temp_lo         int,           -- low temperature
    temp_hi         int,           -- high temperature
    prcp            real,          -- precipitation
    date            date
);
'''

# %%
cur.execute(create)

# %%
conn.commit()

# %%
data = pd.read_csv('C:/Users/vanguiano/Desktop/CoCWebsite/chiscrape/data/data_output.csv', encoding = 'iso-8859-1',index_col='index')
#See http://pandas.pydata.org/pandas-docs/stable/io.html#io-sql for documentation on this
engine = create_engine('postgresql://vanguiano:V1DaL1T0@127.0.0.1:5432/chiscrape_local') 
data.to_sql('data2', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-784f5062fa44> in <module>()
#       2 #See http://pandas.pydata.org/pandas-docs/stable/io.html#io-sql for documentation on this
#       3 engine = create_engine('postgresql://vanguiano:V1DaL1T0@127.0.0.1:5432/chiscrape_local')
# ----> 4 data.to_sql('data2', engine)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1360         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1361                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1362                    chunksize=chunksize, dtype=dtype)
#    1363
#    1364     def to_pickle(self, path, compression='infer'):
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     469     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     470                       index_label=index_label, schema=schema,
# --> 471                       chunksize=chunksize, dtype=dtype)
#     472
#     473
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1148                          if_exists=if_exists, index_label=index_label,
#    1149                          schema=schema, dtype=dtype)
# -> 1150         table.create()
#    1151         table.insert(chunksize)
#    1152         if (not name.isdigit() and not name.islower()):
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     586         if self.exists():
#     587             if self.if_exists == 'fail':
# --> 588                 raise ValueError("Table '%s' already exists." % self.name)
#     589             elif self.if_exists == 'replace':
#     590                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'data2' already exists.

# %%
data2 = pd.read_csv('C:/Users/vanguiano/Desktop/CoCWebsite/chiscrape/data/data_output_2_6_1_14_cleaned.csv' ,encoding = 'iso-8859-1',index_col='Unnamed: 0')

# %%
engine = create_engine('postgresql://cityscrapeMaster:JHjcWXmA?u4bpeaGKmsrQ8j48,Ad@cityscrape.cmkoqli3hwbd.us-east-1.rds.amazonaws.com:5432/cityscrape')

# %%
pdf_data = pd.read_csv('C:/Users/vanguiano/Desktop/ChiPDFs/pdf_assess_results.csv',sep='`')
pdf_data
# Out:
#       Unnamed: 0                                               dept  \
# 0            201  Department of Business Affairs and Consumer Pr...
# 1            204                              Department of Finance
# 2            205  Department of Business Affairs and Consumer Pr...
# 2290  https://www.cityofchicago.org/content/dam/city...     Success
# 2291  https://www.cityofchicago.org/content/dam/city...     Success
# 2292  https://www.cityofchicago.org/content/dam/city...     Success
# 2293  https://www.cityofchicago.org/content/dam/city...     Success
# 2294  https://www.cityofchicago.org/content/dam/city...     Success
# 2295  https://www.cityofchicago.org/content/dam/city...     Success
# 2296  https://www.cityofchicago.org/content/dam/city...     Success
#
#                  fillable                                           pdf_text  \
# 0     Not a fillable PDF.  BUSINESS LICENSE SEARCH\n1]  Go to the Data Po...
# 1     Not a fillable PDF.  City of Chicago\n\nEZ Pay Station Locations\n\...
# 2     Not a fillable PDF.
#
# 3     Not a fillable PDF.   \n\nVOLUNTARY DISCLOSURE AGREEMENT \n\nBETWEE...
# 4     Not a fillable PDF.
#
#
#
#
#
#
#
#
#
#
#
#
# 5     Not a fillable PDF.   \n\n \n\n \n\n \n\n \n\nPharmaceutical Repres...
# 6     Not a fillable PDF.  S M A L L\nBUSINESS\nC E N T ER\n\nWe are comm...
# 7     Not a fillable PDF.  SIDEWALK CAFÉ APPLICATION INFORMATION PACKAGE ...
# 8     Not a fillable PDF.                                     Took too long.
# 9     Not a fillable PDF.   Need a Small Business Loan? \n\n \n\nThe City...
# 10    Not a fillable PDF.  DEPARTMENT  O F BUSINESS AFFAIRS   A ND CONSUM...
# 11    Not a fillable PDF.  DEPARTMENT  O F BUSINESS AFFAIRS   A ND CONSUM...
# 12    Not a fillable PDF.  DEPARTMENT  O F BUSINESS AFFAIRS   A ND CONSUM...
# 13    Not a fillable PDF.   \n\n \n \n \n\nAnimal Care and Services in Ch...
# 14    Not a fillable PDF.  Children’s Services Facilities in Chicago: Wha...
# 15    Not a fillable PDF.   \n\n \n \n \n\nDebt Collectors in Chicago: Wh...
# 16    Not a fillable PDF.   \n\n \n \n \n\nMobile Prepared Food Vendors i...
# 17    Not a fillable PDF.   \n\n \n \n \n\nShared Kitchens in Chicago: Wh...
# 18    Not a fillable PDF.   \n\n \n \n \n\nHome-Based Businesses in Chica...
# 19    Not a fillable PDF.  Home Repair & Construction Services in Chicago...
# 20    Not a fillable PDF.   \n\n \n \n \n\nEarly Sunday Liquor Sales in C...
# 21    Not a fillable PDF.   \n\n \n \n \n\nParking Lots & Public Garages ...
# 22    Not a fillable PDF.  City of Chicago \n\n\nBusiness Affairs and Con...
# 23    Not a fillable PDF.  City of Chicago \n\nBusiness Affairs and Consu...
# 24    Not a fillable PDF.  City of Chicago \n\nOffice of the City Clerk \...
# 25    Not a fillable PDF.   \n\n \n \n \n\nTobacco Dealers in Chicago: Wh...
# 26    Not a fillable PDF.   \n\n3 Simple Steps to Obtain a Business Licen...
# 27    Not a fillable PDF.                                     Took too long.
# 28    Not a fillable PDF.  AUA \n\n \n\n \n\nADULT USE AFFIDAVIT \n\n \n\...
# 29    Not a fillable PDF.                                     Took too long.
# ...                   ...                                                ...
# 2267  Not a fillable PDF.
#
#
#
#
#
#
# 2268  Not a fillable PDF.
#
#
#
#
#
#
# 2269  Not a fillable PDF.   \n\nForm Corporate 2017: to be used only for ...
# 2270  Not a fillable PDF.  Form Corporate 2017: to be used only for Deleg...
# 2271               Failed                                            Failed.
# 2272  Not a fillable PDF.  Quick Start Guide \nif you are new to the EDS ...
# 2273  Not a fillable PDF.   \n \n \n\n \n\n \n\n \n\nRegulating the House...
# 2274  Not a fillable PDF.   \n\naccommodation provided in any building or...
# 2275  Not a fillable PDF.  DEPARTMENT OF FINANCE\n\n Organizational Chart...
# 2276  Not a fillable PDF.    \n\nReporting Chicago Business Tax Fraud  \n...
# 2277  Not a fillable PDF.  HOW TO ADDRESS A PROBLEM\nBUSINESS IN YOUR NEI...
# 2278  Not a fillable PDF.  BEGIN ACTION\n\nFile your \ncomplaint \nonline...
# 2279  Not a fillable PDF.   \n\n \n\nRESTAURANT QUICK GUIDE TO LICENSES, ...
# 2280               Failed                                            Failed.
# 2281  Not a fillable PDF.  SITE AND FLOOR PLANS \n\nSite Plan \n\nFloor P...
# 2282  Not a fillable PDF.      \n\n \n\nWHEN DO I NEED A BUILDING PERMIT?...
# 2283  Not a fillable PDF.   \n\n
#
#  \n\n
# RESTAURANT QUICK GUIDE TO LICENSE...
# 2284  Not a fillable PDF.   \n\nSCHEDULING BUILDING PERMIT INSPECTIONS  \...
# 2285               Failed                                            Failed.
# 2286  Not a fillable PDF.  Application for Occupancy Capacity Signs\n\nBu...
# 2287  Not a fillable PDF.  C I T Y   O F   C H I C A G O\n\nDEPARTMENT OF...
# 2288                  NaN                                                NaN
# 2289  Not a fillable PDF.  1.0 EXECUTIVE SUMMARY  \nThe purpose of this b...
# 2290  Not a fillable PDF.   \n\n \n\n \n \n\n \n \n \n \n \n2\n\n \n\n \n...
# 2291  Not a fillable PDF.  Neighborhood Business Development Centers (NBD...
# 2292  Not a fillable PDF.  City of Chicago Department of Business Affairs...
# 2293  Not a fillable PDF.   \n\n \n\n \n\n \n\n \n\n \n\nCity of Chicago ...
# 2294  Not a fillable PDF.                                     Took too long.
# 2295  Not a fillable PDF.                                     Took too long.
# 2296  Not a fillable PDF.
#
#
#       num_pages
# 0           2.0
# 1           1.0
# 2           0.0
# 3           4.0
# 4          12.0
# 5           7.0
# 6           2.0
# 7          31.0
# 8           0.0
# 9           1.0
# 10          1.0
# 11          1.0
# 12          1.0
# 13          3.0
# 14          4.0
# 15          2.0
# 16          2.0
# 17          4.0
# 18          2.0
# 19          3.0
# 20          2.0
# 21          2.0
# 22         13.0
# 23          2.0
# 24         12.0
# 25          3.0
# 26          2.0
# 27          2.0
# 28          1.0
# 29          3.0
# ...         ...
# 2267        6.0
# 2268        6.0
# 2269        7.0
# 2270       36.0
# 2271        1.0
# 2272        1.0
# 2273        3.0
# 2274       58.0
# 2275        1.0
# 2276        1.0
# 2277        2.0
# 2278        1.0
# 2279        6.0
# 2280       18.0
# 2281       10.0
# 2282       27.0
# 2283       32.0
# 2284       10.0
# 2285        2.0
# 2286        1.0
# 2287        3.0
# 2288        NaN
# 2289       23.0
# 2290       17.0
# 2291        2.0
# 2292        2.0
# 2293        1.0
# 2294        8.0
# 2295        9.0
# 2296        1.0
#
# [2297 rows x 8 columns]

# %%
pdf_data.to_sql('pdf_scrape', engine)

# %%
test = pd.DataFrame(t,columns=['name'])
